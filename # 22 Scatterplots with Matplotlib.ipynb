# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# %%
# Create a quick dataframe
my_df = pd.DataFrame(randn(500, 4), columns=["Mon", "Tues", "Wed", "Thur"])
my_df
# Out:
#           Mon      Tues       Wed      Thur
# 0   -2.955979 -0.709683 -1.416832  0.259074
# 1   -0.223850 -1.610837  1.254018  2.358791
# 2   -0.159331 -1.737955 -1.045948 -1.083829
# 3    1.393076  0.484517  0.343618 -0.275170
# 4   -0.626010 -1.328742  0.525962  0.036544
# ..        ...       ...       ...       ...
# 495  0.025489  0.622775 -1.071064  0.646614
# 496  0.744924  0.015576  0.483267  0.985195
# 497  0.712712 -0.933377  1.207420 -1.196033
# 498 -0.341315  2.074403  1.288791  1.153215
# 499  0.954881 -1.169396  1.313359 -2.232200
#
# [500 rows x 4 columns]

# %%
# Scatteer plot 
my_df.plot(kind="scatter", x="Mon", y="Tues", c="Wed")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Colors: https://matplotlib.org/stable/users/explain/colors/colormaps.html
my_df.plot(kind="scatter", x="Mon", y="Tues", c="Wed", cmap="Set3")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# By size
my_df.plot(kind="scatter", x="Mon", y="Tues", s=my_df["Wed"]*100, cmap="Set3")
# Out:
# /home/dan/Dokumenty/Kursy/Pandas/pandas/lib/python3.11/site-packages/matplotlib/collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# /home/dan/Dokumenty/Kursy/Pandas/pandas/lib/python3.11/site-packages/pandas/plotting/_matplotlib/core.py:1266: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# By Szie easier to read with Aplha
my_df.plot(kind="scatter", x="Mon", y="Tues", s=my_df["Wed"]*100, alpha=.4)
# Out:
# /home/dan/Dokumenty/Kursy/Pandas/pandas/lib/python3.11/site-packages/matplotlib/collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Title Etc
my_df.plot(kind="scatter", x="Mon", y="Tues", s=my_df["Wed"]*100, alpha=.4, title="My Scatter")
# Out:
# /home/dan/Dokumenty/Kursy/Pandas/pandas/lib/python3.11/site-packages/matplotlib/collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: title={'center': 'My Scatter'}, xlabel='Mon', ylabel='Tues'>
