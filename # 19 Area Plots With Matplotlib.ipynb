# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# %%
# Create a quick dataframe
my_df = pd.DataFrame(randn(25, 4), columns=["Mon", "Tues", "Wed", "Thur"])
my_df
# Out:
#          Mon      Tues       Wed      Thur
# 0   1.786968 -0.551428  1.967410  0.233736
# 1   0.078315 -0.115387  0.184158 -0.067074
# 2  -0.647567 -1.960861  0.142593 -0.651281
# 3   0.083391  0.010192 -0.670171 -0.903077
# 4  -0.514923 -0.574874  0.256604  0.831871
# 5  -0.915075  1.058224  1.025139  0.323668
# 6   0.865751  0.838282  0.606504  0.693711
# 7   0.780196  0.438724  1.013332  1.892947
# 8  -0.431847 -0.211391  0.544973 -0.070024
# 9  -0.666591  1.644415 -0.583068 -1.132032
# 10 -0.295936 -0.083425 -0.425858 -0.639396
# 11 -0.009316 -0.103590 -0.195156 -1.378795
# 12  0.030195 -0.213482 -0.088135  0.809442
# 13 -0.055812  0.058758 -0.329335 -0.268463
# 14  0.683006 -0.216324 -0.278286 -1.482522
# 15 -0.139751 -0.523612 -0.001108  0.919295
# 16  0.981802 -1.097572 -0.212938  1.897304
# 17  0.375387  0.279616  0.327712 -0.412910
# 18 -1.244036  0.558293 -1.174196 -0.296438
# 19 -0.782547 -1.113061  0.880369 -0.192074
# 20  0.567615  0.725127 -0.877854 -0.173361
# ...

# %%
# Area plot
my_df.abs().plot(kind='area', stacked=False)
# Out:
# <Axes: >

# %%
# Shading
c
# Out:
# <Axes: >

# %%
# Title
my_df.abs().plot(kind='area', stacked=False, title = "My Plot")
# Out:
# <Axes: title={'center': 'My Plot'}>

# %%
# Legend 
my_df.abs().plot(kind='area', stacked=False, title = "My Plot", legend= False)
# Out:
# <Axes: title={'center': 'My Plot'}>

# %%
# Plot only oune column
my_df["Mon"].abs().plot(kind='area', stacked=False, title = "My Plot", legend= False)
# Out:
# <Axes: title={'center': 'My Plot'}>

# %%
# Plot 2 columns
my_df[["Mon", "Thur"]].abs().plot(kind='area', stacked=False, title = "My Plot", legend= False)
# Out:
# <Axes: title={'center': 'My Plot'}>

# %%
# Get info on function
my_df[["Mon", "Thur"]].plot(kind='area', stacked=False, title = "My Plot", legend= False) # use shift + tab
# Out:
# <Axes: title={'center': 'My Plot'}>

# %%
# Add table
my_df[["Mon", "Thur"]].abs().plot(kind='area', stacked=False, title = "My Plot", legend= False, t)
