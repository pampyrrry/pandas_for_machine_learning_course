# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# %%
# Create a quick dataframe
my_df = pd.DataFrame(randn(500, 4), columns=["Mon", "Tues", "Wed", "Thur"])
my_df
# Out:
#           Mon      Tues       Wed      Thur
# 0   -2.936214  0.430715 -1.110942 -0.367683
# 1    0.631508  1.157123  0.023363 -0.846058
# 2    0.788444  0.263058  0.155084 -0.116650
# 3    0.794015 -1.267831  0.498467 -1.527935
# 4    1.238141 -0.786068 -0.133537 -1.296962
# ..        ...       ...       ...       ...
# 495 -2.566646 -1.282217 -1.590901 -1.039306
# 496  0.334809  0.594018 -1.331348 -0.419771
# 497 -0.602147  1.821021  0.600404  0.302544
# 498 -0.768098  0.717876 -0.302534  1.362883
# 499 -1.075981  0.554832 -0.411827 -0.383373
#
# [500 rows x 4 columns]

# %%
# Boxplots

# %%
my_df.plot(kind="box")
# Out:
# <Axes: >

# %%
# Boxplots Size
my_df.plot(kind="box", figsize=(10,5))
# Out:
# <Axes: >

# %%
# Boxplots Color
my_df.plot(kind="box", figsize=(10,5), cmap="jet")
# Out:
# <Axes: >

# %%
# Legend - doesn't work!

# %%
# Title
my_df.plot(kind="box", figsize=(10,5), cmap="jet", title="Boxplot")
# Out:
# <Axes: title={'center': 'Boxplot'}>

# %%
# Other Way
my_df.plot.box(title="My boxplots 2nd way", grid="True")
# Out:
# <Axes: title={'center': 'My boxplots 2nd way'}>

# %%
my_df.plot.box(title="My boxplots 2nd way", grid="True")
