# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# %%
# Create a quick dataframe
my_df = pd.DataFrame(randn(100, 4), columns=["Mon", "Tues", "Wed", "Thur"])
my_df
# Out:
#          Mon      Tues       Wed      Thur
# 0  -0.806878 -0.679784  0.120788 -0.807878
# 1  -1.181675  0.164454 -0.798725  0.422237
# 2   0.202856  0.313649  1.304160 -1.489185
# 3  -0.691071  1.049060 -0.209054  0.725248
# 4   0.797016 -0.023187  2.196043  1.331575
# ..       ...       ...       ...       ...
# 95  1.711043 -0.886554  0.936712  0.257768
# 96 -0.084185  1.303685  0.541947 -0.774457
# 97 -0.673196  0.203435  0.296758  0.404123
# 98  0.297052 -1.571109  0.435956 -0.922359
# 99 -1.279423 -0.574955  0.498471  1.439601
#
# [100 rows x 4 columns]

# %%
# Histagram
my_df["Wed"].hist()
# Out:
# <Axes: >

# %%
# Histagram with Smaller bins , 50, 20
my_df["Wed"].hist(bins=50)
# Out:
# <Axes: >

# %%
# Antoher way without grid bars
my_df["Wed"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
my_df["Wed"].hist(bins=20, grid = False, legend=True)
# Out:
# <Axes: >
