# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# %%
# Create a quick dataframe
my_df = pd.DataFrame(randn(500, 4), columns=["Mon", "Tues", "Wed", "Thur"])
my_df
# Out:
#           Mon      Tues       Wed      Thur
# 0   -0.112319 -0.661982  1.149032 -0.763334
# 1    0.739628 -0.858685 -0.756291 -0.210613
# 2   -0.097519 -0.092431 -0.619601  0.393175
# 3    0.055178 -0.787747 -0.946167  0.238973
# 4    2.002349  1.037427  0.227571 -1.058347
# ..        ...       ...       ...       ...
# 495 -1.274846 -0.143720  1.866200  1.537372
# 496 -0.205555  1.465223  0.195052  0.679500
# 497  0.273818 -0.051444 -0.102141 -1.168223
# 498 -1.257571 -0.552780  0.620422  2.321312
# 499  0.455881  0.201997 -0.407733  0.453196
#
# [500 rows x 4 columns]

# %%
# Hexplots
my_df.plot(kind="hexbin", x="Mon", y="Tues")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Hexplots size
my_df.plot(kind="hexbin", x="Mon", y="Tues", gridsize=10)
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Hexplots color
my_df.plot(kind="hexbin", x="Mon", y="Tues", gridsize=10, cmap="Wistia")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Other method
my_df.plot.hexbin(x="Mon", y="Tues", gridsize=10, cmap="Wistia")
# Out:
# <Axes: xlabel='Mon', ylabel='Tues'>

# %%
# Title
my_df.plot.hexbin(x="Mon", y="Tues", gridsize=10, cmap="Wistia", title="My hexplot")
# Out:
# <Axes: title={'center': 'My hexplot'}, xlabel='Mon', ylabel='Tues'>

# %%
# Grid
my_df.plot.hexbin(x="Mon", y="Tues", gridsize=10, cmap="Wistia", title="My hexplot", grid=True)
# Out:
# <Axes: title={'center': 'My hexplot'}, xlabel='Mon', ylabel='Tues'>
