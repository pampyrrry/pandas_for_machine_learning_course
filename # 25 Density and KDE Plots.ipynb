# %%
import pandas as pd
import numpy as np
from numpy.random import randn
# %matplotlib inline

# %%
# Create a quick dataframe
my_df = pd.DataFrame(randn(500, 4), columns=["Mon", "Tues", "Wed", "Thur"])
my_df
# Out:
#           Mon      Tues       Wed      Thur
# 0   -1.172325 -0.962307  1.190273  0.222723
# 1   -0.177321 -1.626877 -0.374043  1.688042
# 2   -1.045625 -1.131562 -1.055141 -0.042657
# 3    0.593767  1.139813 -0.220575 -0.816605
# 4   -0.205676 -0.296817 -1.399255  1.814319
# ..        ...       ...       ...       ...
# 495  0.984390  0.804287  0.362988 -1.507299
# 496 -0.167053 -0.494043 -1.072148  0.342459
# 497 -0.507082 -0.921348 -0.751126 -0.590200
# 498  1.163677  0.666506 -0.129346  1.641077
# 499 -0.266123  0.236465  0.162846 -1.247233
#
# [500 rows x 4 columns]

# %%
my_df.plot(kind="kde")
# Out:
# <Axes: ylabel='Density'>

# %%
# KDE second way to Learn shift tab
my_df.plot.kde()
# Out:
# <Axes: ylabel='Density'>

# %%
# Density Plot
my_df.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %%
# Othe method
my_df.plot(kind="density")
# Out:
# <Axes: ylabel='Density'>

# %%
# Title
my_df.plot(kind="density", title="My density plot")
# Out:
# <Axes: title={'center': 'My density plot'}, ylabel='Density'>

# %%
# change stuff
my_df.plot(kind="density", title="My density plot", alpha=.4, lw=4, grid=True)
# Out:
# <Axes: title={'center': 'My density plot'}, ylabel='Density'>

# %%
my_df["Tues"].plot(kind="density", title="My density plot", alpha=.4, lw=4, grid=True)
# Out:
# <Axes: title={'center': 'My density plot'}, ylabel='Density'>
