# %%
import pandas as pd
import numpy as np

# %%
# Create Data
stuff = {
    'Corporation': ['Apple', 'Google', 'Meta', 'Apple', 'Google', 'Meta'],
    'Employees': ['John', 'April', 'Wes', 'Beth', 'Justin', 'Steph'],
    'Salary': [200, 220, 190, 130, 120, 150]}

# %%
# Create Dataframe
my_df = pd.DataFrame(stuff)
my_df
# Out:
#   Corporation Employees  Salary
# 0       Apple      John     200
# 1      Google     April     220
# 2        Meta       Wes     190
# 3       Apple      Beth     130
# 4      Google    Justin     120
# 5        Meta     Steph     150

# %%
# Sort Salaries from Lowest to Highest 
my_df.sort_values("Salary")
# Out:
#   Corporation Employees  Salary
# 4      Google    Justin     120
# 3       Apple      Beth     130
# 5        Meta     Steph     150
# 2        Meta       Wes     190
# 0       Apple      John     200
# 1      Google     April     220

# %%
# Sort Salaries Highest to Lowerst
my_df.sort_values("Salary", ascending=False)
my_df
# Out:
#   Corporation Employees  Salary
# 1      Google     April     220
# 0       Apple      John     200
# 2        Meta       Wes     190
# 5        Meta     Steph     150
# 3       Apple      Beth     130
# 4      Google    Justin     120

# %%
# Not Permanent without inplace=True
my_df
# Out:
#   Corporation Employees  Salary
# 0       Apple      John     200
# 1      Google     April     220
# 2        Meta       Wes     190
# 3       Apple      Beth     130
# 4      Google    Justin     120
# 5        Meta     Steph     150

# %%
# In place
my_df.sort_values("Salary", ascending = False, inplace = True)
my_df
# Out:
#   Corporation Employees  Salary
# 1      Google     April     220
# 0       Apple      John     200
# 2        Meta       Wes     190
# 5        Meta     Steph     150
# 3       Apple      Beth     130
# 4      Google    Justin     120

# %%
# Sort String Alphabeticaly
my_df.sort_values('Corporation')
# Out:
#   Corporation Employees  Salary
# 0       Apple      John     200
# 3       Apple      Beth     130
# 1      Google     April     220
# 4      Google    Justin     120
# 2        Meta       Wes     190
# 5        Meta     Steph     150

# %%
# Sort String Alphabeticaly Descending 
my_df.sort_values('Corporation', ascxendib)
